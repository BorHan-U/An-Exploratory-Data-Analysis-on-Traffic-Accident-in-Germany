# %%
Introduction:

# %%
#To conduct an EDA (Exploratory data analysis), we required several python library. Using !pip, we Install necessary libraries below:

# !pip install matplotlib 
# !pip install numpy 
# !pip install pandas
# Out:
# Collecting matplotlib
#   Downloading matplotlib-3.8.4-cp311-cp311-macosx_10_12_x86_64.whl.metadata (5.8 kB)
# Collecting contourpy>=1.0.1 (from matplotlib)
#   Downloading contourpy-1.2.1-cp311-cp311-macosx_10_9_x86_64.whl.metadata (5.8 kB)
# Collecting cycler>=0.10 (from matplotlib)
#   Using cached cycler-0.12.1-py3-none-any.whl.metadata (3.8 kB)
# Collecting fonttools>=4.22.0 (from matplotlib)
#   Downloading fonttools-4.51.0-cp311-cp311-macosx_10_9_x86_64.whl.metadata (159 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 159.5/159.5 kB 2.5 MB/s eta 0:00:00a 0:00:01
# Collecting kiwisolver>=1.3.1 (from matplotlib)
#   Downloading kiwisolver-1.4.5-cp311-cp311-macosx_10_9_x86_64.whl.metadata (6.4 kB)
# Collecting numpy>=1.21 (from matplotlib)
#   Downloading numpy-1.26.4-cp311-cp311-macosx_10_9_x86_64.whl.metadata (61 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.1/61.1 kB 1.8 MB/s eta 0:00:00
# Requirement already satisfied: packaging>=20.0 in /Users/borhan/miniconda3/lib/python3.11/site-packages (from matplotlib) (23.1)
# Collecting pillow>=8 (from matplotlib)
#   Downloading pillow-10.3.0-cp311-cp311-macosx_10_10_x86_64.whl.metadata (9.2 kB)
# Collecting pyparsing>=2.3.1 (from matplotlib)
#   Downloading pyparsing-3.1.2-py3-none-any.whl.metadata (5.1 kB)
# Collecting python-dateutil>=2.7 (from matplotlib)
#   Downloading python_dateutil-2.9.0.post0-py2.py3-none-any.whl.metadata (8.4 kB)
# Collecting six>=1.5 (from python-dateutil>=2.7->matplotlib)
#   Using cached six-1.16.0-py2.py3-none-any.whl.metadata (1.8 kB)
# Downloading matplotlib-3.8.4-cp311-cp311-macosx_10_12_x86_64.whl (7.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.6/7.6 MB 7.8 MB/s eta 0:00:0000:0100:01
# Downloading contourpy-1.2.1-cp311-cp311-macosx_10_9_x86_64.whl (262 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 262.1/262.1 kB 5.1 MB/s eta 0:00:00:00:01
# Using cached cycler-0.12.1-py3-none-any.whl (8.3 kB)
# Downloading fonttools-4.51.0-cp311-cp311-macosx_10_9_x86_64.whl (2.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.3/2.3 MB 8.1 MB/s eta 0:00:0000:0100:01m
# Downloading kiwisolver-1.4.5-cp311-cp311-macosx_10_9_x86_64.whl (68 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 68.2/68.2 kB 1.9 MB/s eta 0:00:00
# Downloading numpy-1.26.4-cp311-cp311-macosx_10_9_x86_64.whl (20.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 20.6/20.6 MB 8.3 MB/s eta 0:00:0000:0100:01
# Downloading pillow-10.3.0-cp311-cp311-macosx_10_10_x86_64.whl (3.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.5/3.5 MB 8.6 MB/s eta 0:00:0000:0100:01
# Downloading pyparsing-3.1.2-py3-none-any.whl (103 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 103.2/103.2 kB 3.1 MB/s eta 0:00:00
# Downloading python_dateutil-2.9.0.post0-py2.py3-none-any.whl (229 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 229.9/229.9 kB 4.3 MB/s eta 0:00:0000:01
# Using cached six-1.16.0-py2.py3-none-any.whl (11 kB)
# Installing collected packages: six, pyparsing, pillow, numpy, kiwisolver, fonttools, cycler, python-dateutil, contourpy, matplotlib
# Successfully installed contourpy-1.2.1 cycler-0.12.1 fonttools-4.51.0 kiwisolver-1.4.5 matplotlib-3.8.4 numpy-1.26.4 pillow-10.3.0 pyparsing-3.1.2 python-dateutil-2.9.0.post0 six-1.16.0
# Requirement already satisfied: numpy in /Users/borhan/miniconda3/lib/python3.11/site-packages (1.26.4)
# Collecting pandas
#   Downloading pandas-2.2.2-cp311-cp311-macosx_10_9_x86_64.whl.metadata (19 kB)
# Requirement already satisfied: numpy>=1.23.2 in /Users/borhan/miniconda3/lib/python3.11/site-packages (from pandas) (1.26.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in /Users/borhan/miniconda3/lib/python3.11/site-packages (from pandas) (2.9.0.post0)
# Collecting pytz>=2020.1 (from pandas)
#   Using cached pytz-2024.1-py2.py3-none-any.whl.metadata (22 kB)
# Collecting tzdata>=2022.7 (from pandas)
#   Downloading tzdata-2024.1-py2.py3-none-any.whl.metadata (1.4 kB)
# Requirement already satisfied: six>=1.5 in /Users/borhan/miniconda3/lib/python3.11/site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)
# Downloading pandas-2.2.2-cp311-cp311-macosx_10_9_x86_64.whl (12.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.6/12.6 MB 7.7 MB/s eta 0:00:0000:0100:01
# Using cached pytz-2024.1-py2.py3-none-any.whl (505 kB)
# Downloading tzdata-2024.1-py2.py3-none-any.whl (345 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 345.4/345.4 kB 5.0 MB/s eta 0:00:00a 0:00:01
# Installing collected packages: pytz, tzdata, pandas
# Successfully installed pandas-2.2.2 pytz-2024.1 tzdata-2024.1

# %%
#Since we had installed all libraries, to make them use, we import it to notebook.

import pandas as pd
import numpy as np
from matplotlib import pyplot as plt 
import seaborn as sns

# %%
#Data preprocessing:

#In this step, we load the datasets from the data directory.

dataset_path = "/Users/borhan/Desktop/Potsdam Study/Research Software/Project_RSE_824909/data/Traffic accident.csv"

# %%
# Using pandas we read the dataset as dataframe, A dataframe is a data structure constructed with rows and columns, similar to a database or Excel spreadsheet. It allows data to align in a tabular fashion in rows and columns

df = pd.read_csv(dataset_path)

# Display the first few rows of the dataframe

df.head()
# Out:
#    Year  Persons killed  Seriously injured  Slightly injured  \
# 0  2008             288               6797             18293
# 1  2009             294               6719             18346
# 2  2010             251               5864             16825
# 3  2011             244               6459             16602
# 4  2012             221               6177             16626
#
#    Kind of accident   Area type
# 0  Driving accident  inner town
# 1  Driving accident  inner town
# 2  Driving accident  inner town
# 3  Driving accident  inner town
# 4  Driving accident  inner town

# %%
#To check the dataset's total columns and rows to get an overview of rows and coulumn.

print("Number of rows and columns:", df.shape)
# Out:
# Number of rows and columns: (90, 6)

# %%
# Before heading to analyse data, we need to check certain inconsistency in datasets which are a part data preprocessing. Check for missing values in datsets in one of them.

df.isnull().sum()
# Out:
# Year                 0
# Persons killed       0
# Seriously injured    0
# Slightly injured     0
# Kind of accident     0
# Area type            0
# dtype: int64

# %%
# There are two kind of values in datsets: categorical and numerical. this code snippet provides a Summary statistics for categorical columns

df.describe(include=['object'])
# Out:
#         Kind of accident   Area type
# count                 90          90
# unique                 3           2
# top     Driving accident  inner town
# freq                  30          45

# %%
#This code snippet allows us to quickly visualize the distribution of each numerical variable in our dataset. So, below are the histogram that gives an overall insight about all numerical columns in our datasets and eventually we can see there are 4 numerical coulumns.

# Histograms
df.hist(figsize=(12, 8))
plt.show()

# %%
#This code snippet allows us to quickly visualize the correlation between pairs of numerical variables in our dataset.
# Correlation matrix
corr = df.corr()
sns.heatmap(corr, annot=True, cmap='coolwarm', fmt=".2f")
plt.show()

# %%
# To understand data better, the datasets includes three kinds of accident, here are the types

# Count plot for type of accident
plt.figure(figsize=(10, 6))
sns.countplot(x='Kind of accident', data=df)
plt.title('Count of Different Types of Accidents')
plt.xlabel('Type of Accident')
plt.ylabel('Count')
plt.xticks(rotation=45)
plt.show()

# %%
# Over the 15 yearts of accident report in dataset, the Plot below shows the number of deaths and  other injuries over the years

plt.figure(figsize=(12, 6))
sns.lineplot(x='Year', y='Persons killed', data=df, label='Deaths')
sns.lineplot(x='Year', y='Seriously injured', data=df, label='Seriously Injured')
sns.lineplot(x='Year', y='Slightly injured', data=df, label='Slightly Injured')
plt.title('Number of Deaths and Injuries over the Years')
plt.xlabel('Year')
plt.ylabel('Count')
plt.legend()
plt.show()

# %%
#Research question -1: During the crossing road, which year mostly death cases occurred in inner town?

inner_town_crossing = df[(df['Kind of accident'] == 'Crossing accident') & (df['Area type'] == 'inner town')]

# Group by year and sum the number of deaths
death_by_year = inner_town_crossing.groupby('Year')['Persons killed'].sum()

# Find the year with the maximum number of deaths
most_death_year = death_by_year.idxmax()
max_death_count = death_by_year.max()

print("During crossing the road, the most death cases occurred in the inner town in the year:", most_death_year)
print("Number of death cases:", max_death_count)


print ("------------------------------------------------------------------------------------------------------")

#Visialization of research question:

print ("To get and overview of most death cases shorter time in mentione condition, we may visualise is as such")

# Group by year and sum the number of deaths
death_by_year = inner_town_crossing.groupby('Year')['Persons killed'].sum().reset_index()

# Plot the number of death cases by year
plt.figure(figsize=(10, 6))
plt.bar(death_by_year['Year'], death_by_year['Persons killed'], color='skyblue')
plt.title('Number of Death Cases in Inner Town During Crossing the Road by Year')
plt.xlabel('Year')
plt.ylabel('Number of Death Cases')
plt.xticks(rotation=45)
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.show()
# Out:
# During crossing the road, the most death cases occurred in the inner town in the year: 2008
# Number of death cases: 181
# ------------------------------------------------------------------------------------------------------
# To get and overview of most death cases shorter time in mentione condition, we may visualise is such

# %%
# Reasearch Question 2: What are the main types of accident that causes most death case over the years?


# Group by type of accident and sum the number of deaths
death_by_accident = df.groupby('Kind of accident')['Persons killed'].sum().reset_index()

# Sort the dataframe by the number of deaths
death_by_accident_sorted = death_by_accident.sort_values(by='Persons killed', ascending=False)

# Plot the number of death cases by type of accident
plt.figure(figsize=(10, 6))
sns.barplot(x='Persons killed', y='Kind of accident', data=death_by_accident_sorted, palette='viridis')
plt.title('Number of Death Cases by Type of Accident')
plt.xlabel('Number of Death Cases')
plt.ylabel('Type of Accident')
plt.show()

# Print the main types of accidents causing the most death cases
print("Main types of accidents causing the most death cases:")
print(death_by_accident_sorted.head())
# Out:
# Main types of accidents causing the most death cases:
#     Kind of accident  Persons killed
# 1   Driving accident           15648
# 0  Crossing accident            5861
# 2   Turning accident            3288

# %%
#Research Question 3: For Which area (inner town/out of town) has the least serious injury over the period?

# Group by city of accident and sum the number of serious injuries
serious_injuries_by_city = df.groupby('Area type')['Seriously injured'].sum().reset_index()

# Find the city with the least serious injuries
city_least_serious_injuries = serious_injuries_by_city[serious_injuries_by_city['Seriously injured'] == serious_injuries_by_city['Seriously injured'].min()]

print("City with the least serious injuries over the period:")
print(city_least_serious_injuries)


print ("------------------------------------------------------------------------------------------------------")

print ("To get and overview of least serious injury between the location, lets visualize both area type")

#Visialization of research question:

# Plot the number of serious injuries by city
plt.figure(figsize=(8, 6))
plt.bar(serious_injuries_by_city['Area type'], serious_injuries_by_city['Seriously injured'], color='skyblue')
plt.title('Number of Serious Injuries by City with Distinct Years')
plt.xlabel('City of Accident')
plt.ylabel('Number of Serious Injuries')
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.show()
# Out:
# Object `period` not found.
# City with the least serious injuries over the period:
#     Area type  Seriously injured
# 0  inner town             276921
# ------------------------------------------------------------------------------------------------------
# To get and overview of least serious injury between the location, lets visualize both area type

# %%
#Research Question - 4: What are the turning accident (one of the accident type) trends between the year 2013 to 2022 that fluctuated in term of slightly injured occurance


# Filter the dataset for turning accidents between the years 2013 to 2022
turning_accidents = df[(df['Kind of accident'] == 'Turning accident') & (df['Year'] >= 2013) & (df['Year'] <= 2022)]

# Group by year and calculate the total number of slightly injured occurrences
slightly_injured_trends = turning_accidents.groupby('Year')['Slightly injured'].sum().reset_index()

# Print the turning accident trends in terms of slightly injured occurrences
print("Turning accident trends between the years 2013 to 2022 in terms of slightly injured occurrences:")
print(slightly_injured_trends)

#visualize------------------


# Plot the turning accident trends in terms of slightly injured occurrences
plt.figure(figsize=(10, 6))
plt.plot(slightly_injured_trends['Year'], slightly_injured_trends['Slightly injured'], marker='o', color='b', linestyle='-')
plt.title('Turning Accident Trends in Terms of Slightly Injured Occurrences (2013-2022)')
plt.xlabel('Year')
plt.ylabel('Number of Slightly Injured')
plt.grid(True)
plt.xticks(slightly_injured_trends['Year'])
plt.show()
# Out:
# Turning accident trends between the years 2013 to 2022 in terms of slightly injured occurrences:
#    Year  Slightly injured
# 0  2013             33505
# 1  2014             34929
# 2  2015             35163
# 3  2016             34618
# 4  2017             34078
# 5  2018             35339
# 6  2019             33947
# 7  2020             29413
# 8  2021             27631
# 9  2022             31268

# %%
#Research Question - 5: How have the number of deaths, serious injuries, and slightly injured cases varied in recent (last 5 years) years due to driving accidents?

# Filter the dataset for driving accidents in the last 5 years
driving_accidents_recent = df[(df['Kind of accident'] == 'Driving accident') & (df['Year'] >= df['Year'].max() - 4)]

# Group by year and calculate the total number of deaths, serious injuries, and slightly injured cases
driving_accidents_trends = driving_accidents_recent.groupby('Year')[['Persons killed', 'Seriously injured', 'Slightly injured']].sum().reset_index()

# Plot trends for driving accidents in the last 5 years
plt.figure(figsize=(10, 6))
for col in ['Persons killed', 'Seriously injured', 'Slightly injured']:
    plt.plot(driving_accidents_trends['Year'], driving_accidents_trends[col], label=f'{col}')

plt.title('Trends in Number of Deaths, Serious Injuries, and Slightly Injured Cases due to Driving Accidents (Last 5 Years)')
plt.xlabel('Year')
plt.ylabel('Count')
plt.legend()
plt.grid(True)
plt.show()

# %%
# Research Question 4: Is there any correlation between the severity of accidents and the number of deaths or injuries?

# Correlation matrix
plt.figure(figsize=(10, 6))
sns.heatmap(df.corr(), annot=True, cmap='coolwarm')
plt.title('Correlation Matrix')
plt.show()

# %%
# Explore relationship between kind of accident and injury severity (if injury columns are numerical)
sns.boxplot(x='Kind of accident', y='Persons killed', data=df)  # Repeat for other injury columns
plt.show()

# %%
# Explore city-wise distribution of accidents (may need further cleaning of city names)
df['Areas'].value_counts().plot(kind='bar')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/indexes/base.py:3361, in Index.get_loc(self, key, method, tolerance)
#    3360 try:
# -> 3361     return self._engine.get_loc(casted_key)
#    3362 except KeyError as err:
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/pandas/_libs/index.pyx:76, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/pandas/_libs/index.pyx:108, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:5198, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:5206, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Areas'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Input In [76], in <cell line: 2>()
#       1 # Explore city-wise distribution of accidents (may need further cleaning of city names)
# ----> 2 df['Areas'].value_counts().plot(kind='bar')
#       3 plt.show()
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/frame.py:3458, in DataFrame.__getitem__(self, key)
#    3456 if self.columns.nlevels > 1:
#    3457     return self._getitem_multilevel(key)
# -> 3458 indexer = self.columns.get_loc(key)
#    3459 if is_integer(indexer):
#    3460     indexer = [indexer]
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/indexes/base.py:3363, in Index.get_loc(self, key, method, tolerance)
#    3361         return self._engine.get_loc(casted_key)
#    3362     except KeyError as err:
# -> 3363         raise KeyError(key) from err
#    3365 if is_scalar(key) and isna(key) and not self.hasnans:
#    3366     raise KeyError(key)
#
# KeyError: 'Areas'

# %%
# Assuming 'kind of accident' is a categorical column (e.g., 'collision', 'fall', etc.)
correlation = df.groupby('Kind of accident')['Seriously injured'].mean()
print(correlation)
# Out:
# Kind of accident
# Crossing accident     5245.833333
# Driving accident     10009.500000
# Turning accident      3347.433333
# Name: Seriously injured, dtype: float64
